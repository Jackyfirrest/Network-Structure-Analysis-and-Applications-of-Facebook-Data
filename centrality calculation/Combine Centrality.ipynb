# %%
from operator import index
import os
import pandas as pd


def extract_week(s:str)->str:
    return s.split('_')[0]


def combine_centralities(s:str):

    file_list = [file for file in os.listdir(s) if file.endswith('.csv')]
    week_list = [extract_week(week) for week in file_list]

    df = pd.DataFrame()

    for week, file in zip(week_list,file_list):
        newdf = pd.read_csv(f"Result/{file}")
        newdf.eigenvector_centrality = abs(newdf.eigenvector_centrality)
        newdf['week'] = week
        df = df.append(newdf, ignore_index=True)

    df.to_csv('Full_Centrality_with_politician.csv')

    return df

# %%
path = "C:/Users/Jackyfirst/Downloads/BDSRC/research/centrality calculation/Result"

# %%
combine_centralities(path)
# Out:
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
# C:\Users\Jackyfirst\AppData\Local\Temp\ipykernel_5900\2983474277.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf, ignore_index=True)
#                page_id  degree_centrality  eigenvector_centrality  \
# 0          15704546335            0.06374            5.179591e-01
# 1         153080620724            0.05870            5.626093e-01
# 2      346937065399354            0.04224            7.584528e-03
# 3          18468761129            0.04164            4.742765e-03
# 4      205344452828349            0.04002            3.020016e-03
# ...                ...                ...                     ...
# 26483  216940628328775            0.00000            1.430985e-18
# 26484  362232687500262            0.00000            1.567738e-18
# 26485  171054229642299            0.00000            2.339076e-21
# 26486  516676641828189            0.00000            5.580462e-18
# 26487     310937177514            0.00000            4.740436e-18
#
#        closeness_centrality  unweighted_eigenvector_centrality_x  \
# 0                  0.356241                         4.638153e-01
# 1                  0.352377                         4.006133e-01
# 2                  0.347411                         6.358647e-02
# 3                  0.347417                         6.326908e-02
# 4                  0.348235                         5.442979e-02
# ...                     ...                                  ...
# 26483              0.000000                         2.068588e-17
# 26484              0.000000                         2.562957e-18
# 26485              0.000000                         6.235870e-18
# 26486              0.000000                         2.957511e-17
# 26487              0.000000                         6.105162e-18
#
#        unweighted_eigenvector_centrality_y        week  Unnamed: 0
# 0                             4.638153e-01  2016-07-31         NaN
# 1                             4.006133e-01  2016-07-31         NaN
# 2                             6.358647e-02  2016-07-31         NaN
# 3                             6.326908e-02  2016-07-31         NaN
# 4                             5.442979e-02  2016-07-31         NaN
# ...                                    ...         ...         ...
# 26483                         1.405150e-17        Full     13239.0
# 26484                         2.471509e-17        Full     13240.0
# 26485                         2.477438e-17        Full     13241.0
# 26486                         1.672749e-17        Full     13242.0
# 26487                         1.257016e-18        Full     13243.0
#
# [26488 rows x 8 columns]
